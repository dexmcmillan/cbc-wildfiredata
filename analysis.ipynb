# %%
import pandas as pd
import glob

# %%
csvfiles = glob.glob("data/*.csv")

dfs = []

for file in csvfiles:
    df = pd.read_csv(file)
    
    dfs.append(df)
    
data = pd.concat(dfs)

data
# Out:
#     Unnamed: 0 agency       firename      lat      lon             startdate  \
# 0            0     pc        2022RM1  50.7606 -99.6775   2022-05-25 14:37:57
# 1            1     nt       FS004-22  63.7368 -121.369   2022-06-02 22:49:00
# 2            2     nt       FS003-22  62.1872  -121.94   2022-06-02 22:58:00
# 3            3     yt      2022WL001  60.0275 -128.745   2022-05-23 03:49:00
# 4            4     bc    2022-G80265  57.3972 -122.377   2022-06-03 22:56:00
# ..         ...    ...            ...      ...      ...                   ...
# 187        187     sk     23BR-AIR02  53.3602 -106.898   2023-05-07 16:47:43
# 188        188     bc    2023-G80190  56.3376 -121.101   2023-05-03 23:46:00
# 189        189     sk  23BN-VERMETTE  55.6443 -109.219   2023-04-29 19:52:08
# 190        190     nb          61223  45.9474 -66.8425   2023-05-08 01:56:38
# 191        191     bc    2023-G30210  53.2884 -120.071   2023-05-05 00:01:00
#
#     hectares stage_of_control                  timestamp
# 0      400.0               UC  2022-06-14 12:37:45+00:00
# 1      190.0               OC  2022-06-14 12:37:45+00:00
# 2     1211.0               OC  2022-06-14 12:37:45+00:00
# 3        2.0               UC  2022-06-14 12:37:45+00:00
# 4      545.0               UC  2022-06-14 12:37:45+00:00
# ..       ...              ...                        ...
# 187     13.0               OC        2023-05-08 10:36:31
# 188     60.0               UC        2023-05-08 10:36:31
# 189  12000.0               OC        2023-05-08 10:36:31
# 190      0.1               BH        2023-05-08 10:36:31
# 191   1100.0               BH        2023-05-08 10:36:31
#
# [446532 rows x 9 columns]

# %%
pivot = data.loc[data["agency"] != "ak", :].pivot_table(index="firename", values="timestamp", aggfunc="nunique").sort_values("timestamp", ascending=False)

pivot.head(5)
# Out:
#                timestamp
# firename
# MWF-022-2022        1121
# Moose                957
# SS018-22             939
# Diamond Watch        931
# 2022-R90436          904

# %%
pivot["duration"] = (pivot["timestamp"] * 2) / 24

pivot.head(5)
# Out:
#                timestamp   duration
# firename
# MWF-022-2022        1121  93.416667
# Moose                957  79.750000
# SS018-22             939  78.250000
# Diamond Watch        931  77.583333
# 2022-R90436          904  75.333333

# %%
data = data.dropna(subset="startdate")

# %%
data[data["startdate"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, agency, firename, lat, lon, startdate, hectares, stage_of_control, timestamp]
# Index: []

# %%
data["startdate"] = pd.to_datetime(data["startdate"], errors="coerce")
# Out:
# C:\Users\dexmc\AppData\Local\Temp\ipykernel_45304\4210336447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["startdate"] = pd.to_datetime(data["startdate"], errors="coerce")

# %%
starts = data[["firename", "startdate"]].groupby("firename").min()

starts.head(5)
# Out:
#                       startdate
# firename
# 01-005-2022 2022-07-25 18:54:37
# 01-006-2022 2022-07-28 07:00:00
# 01-007-2022 2022-09-16 07:00:00
# 03-005-2022 2022-07-11 22:00:00
# 03-006-2022 2022-08-05 07:00:00

# %%
pivot = pivot.join(starts)

pivot
# Out:
#                timestamp   duration           startdate
# firename
# MWF-022-2022        1121  93.416667 2022-06-14 00:43:00
# Moose                957  79.750000 2022-07-17 16:00:00
# SS018-22             939  78.250000 2022-06-16 23:06:00
# Diamond Watch        931  77.583333 2022-07-14 18:00:00
# 2022-R90436          904  75.333333 2022-07-03 01:10:00
# ...                  ...        ...                 ...
# SWF-152-2022           1   0.083333 2022-09-07 15:47:00
# 2022-K42101            1   0.083333 2022-08-28 18:07:00
# 2023-N20204            1   0.083333 2023-05-04 19:13:00
# 2022-K42490            1   0.083333 2022-09-24 17:26:00
# GWF-047-2022           1   0.083333 2022-08-20 19:30:00
#
# [4304 rows x 3 columns]

# %%
fire1 = data[data["firename"] == "MWF-022-2022"] 

fire1
# Out:
#     Unnamed: 0 agency      firename      lat      lon           startdate  \
# 78          78     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 68          68     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 61          61     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 55          55     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 52          52     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# ..         ...    ...           ...      ...      ...                 ...
# 138        138     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 134        134     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 134        134     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 136        136     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
# 131        131     ab  MWF-022-2022  59.4184 -110.813 2022-06-14 00:43:00
#
#     hectares stage_of_control                  timestamp
# 78      40.0               BH  2022-06-14 12:37:45+00:00
# 68      40.0               BH  2022-06-14 14:37:50+00:00
# 61      40.0               BH  2022-06-14 16:37:33+00:00
# 55      40.0               BH  2022-06-14 18:37:38+00:00
# 52      40.0               BH  2022-06-14 20:38:03+00:00
# ..       ...              ...                        ...
# 138  33207.1               UC  2022-10-31 09:50:15+00:00
# 134  33207.1               UC  2022-10-31 12:53:13+00:00
# 134  33207.1               UC  2022-10-31 15:51:32+00:00
# 136  33207.1               UC  2022-10-31 18:50:22+00:00
# 131  33207.1               UC  2022-10-31 21:50:20+00:00
#
# [1121 rows x 9 columns]

# %%
data[data["firename"] == "EWF-031-2023"].sort_values("startdate", ascending=True).set_index("timestamp")[["hectares"]].plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>
